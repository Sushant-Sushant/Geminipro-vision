# %%
# !pip install google-generativeai

# %%
import google.generativeai as gai
gai.configure(api_key='AIzaSyC7aCS-yqdLW-1DyhuZg5vzSSwXgtKOAXo')
for m in gai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
import os
from PIL import Image
img_path=input('enter image path:')
if not os.path.isfile(img_path):
    raise SystemExit('invalid image')
img=Image.open(img_path)
img
# Out:
# enter image path: Downloads/WIN_20240405_16_27_00_Pro.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720>

# %%
import time
from PIL import Image
import google.generativeai as gai
model=gai.GenerativeModel('gemini-pro-vision')
img_path=input('enter image path:')
img=Image.open(img_path)
while True:
    prompt=input('user:')
    if prompt.lower() not in ['radhe radhe','bye','quit']:
        response=model.generate_content([prompt,img])
        print('')
        print(response.text)
        print('='*100)
    else:
        print('exiting...')
        time.sleep(2)
        print('see you..')
        break
